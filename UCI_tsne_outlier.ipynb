# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
import stats
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#Import hdma dataset
df_uci = pd.read_csv(r'C:\Users\jordy\OneDrive\MSc_Python\Individual_Project\Data\UCI_Credit_Card.csv', index_col=0)
df_uci
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 1        20000.0    2          2         1   24      2      2     -1     -1
# 2       120000.0    2          2         2   26     -1      2      0      0
# 3        90000.0    2          2         2   34      0      0      0      0
# 4        50000.0    2          2         1   37      0      0      0      0
# 5        50000.0    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29996   220000.0    1          3         1   39      0      0      0      0
# 29997   150000.0    1          3         2   43     -1     -1     -1     -1
# 29998    30000.0    1          2         2   37      4      3      2     -1
# 29999    80000.0    1          3         1   41      1     -1      0      0
# 30000    50000.0    1          2         1   46      0      0      0      0
#
# ...

# %% [markdown]
# ## TSNE Perplexity 30

# %%
# Drop the target column
features = df_uci.drop(columns=['default.payment.next.month'])

# Standardize the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Perform t-SNE
tsne = TSNE(n_components=2, random_state=42)

# Fit and transform the scaled features with a progress bar
tsne_result = []
with tqdm(total=len(scaled_features), desc="t-SNE Progress") as pbar:
    for i in range(0, len(scaled_features), 100):  # Batch processing for better performance
        batch_result = tsne.fit_transform(scaled_features[i:i+100])
        tsne_result.append(batch_result)
        pbar.update(len(batch_result))

# Concatenate the t-SNE results
tsne_result = np.concatenate(tsne_result, axis=0)

# Create a new DataFrame with the t-SNE results
tsne_df = pd.DataFrame(data=tsne_result, columns=['Dimension 1', 'Dimension 2'])

# Plot the t-SNE scatter plot
plt.scatter(tsne_df['Dimension 1'], tsne_df['Dimension 2'])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('t-SNE Plot')
plt.show()
# Out:
# t-SNE Progress:   0%|                                                                        | 0/30000 [00:00<?, ?it/s]C:\Users\jordy\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# C:\Users\jordy\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# t-SNE Progress:   0%|▏                                                            | 100/30000 [00:00<01:44, 287.35it/s]C:\Users\jordy\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# C:\Users\jordy\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# ...

# %% [markdown]
# ## TSNE iteration = 2000

# %%
# Drop the target column
features = df_uci.drop(columns=['default.payment.next.month'])

# Standardize the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Perform t-SNE
tsne = TSNE(n_components=2, random_state=42, n_iter=2000 )

# Fit and transform the scaled features with a progress bar
tsne_result = []
with tqdm(total=len(scaled_features), desc="t-SNE Progress") as pbar:
    for i in range(0, len(scaled_features), 100):  # Batch processing for better performance
        batch_result = tsne.fit_transform(scaled_features[i:i+100])
        tsne_result.append(batch_result)
        pbar.update(len(batch_result))

# Concatenate the t-SNE results
tsne_result = np.concatenate(tsne_result, axis=0)

# Create a new DataFrame with the t-SNE results
tsne_df = pd.DataFrame(data=tsne_result, columns=['Dimension 1', 'Dimension 2'])

# Plot the t-SNE scatter plot
plt.scatter(tsne_df['Dimension 1'], tsne_df['Dimension 2'])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('t-SNE Plot')
plt.show()
# Out:
# t-SNE Progress:   0%|                                                                        | 0/30000 [00:00<?, ?it/s]C:\Users\jordy\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# C:\Users\jordy\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# t-SNE Progress:   0%|▏                                                            | 100/30000 [00:00<01:45, 284.01it/s]C:\Users\jordy\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# C:\Users\jordy\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# ...

# %% [markdown]
# # TSNE Perplexity 80

# %%
# Drop the target column
features = df_uci.drop(columns=['default.payment.next.month'])

# Standardize the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Perform t-SNE
tsne = TSNE(n_components=2, random_state=42, n_iter=2000, perplexity=80.0)

# Fit and transform the scaled features with a progress bar
tsne_result = []
with tqdm(total=len(scaled_features), desc="t-SNE Progress") as pbar:
    for i in range(0, len(scaled_features), 100):  # Batch processing for better performance
        batch_result = tsne.fit_transform(scaled_features[i:i+100])
        tsne_result.append(batch_result)
        pbar.update(len(batch_result))

# Concatenate the t-SNE results
tsne_result = np.concatenate(tsne_result, axis=0)

# Create a new DataFrame with the t-SNE results
tsne_df = pd.DataFrame(data=tsne_result, columns=['Dimension 1', 'Dimension 2'])

# Plot the t-SNE scatter plot
plt.scatter(tsne_df['Dimension 1'], tsne_df['Dimension 2'])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('t-SNE Plot')
plt.show()
# Out:
# t-SNE Progress:   0%|                                                                        | 0/30000 [00:00<?, ?it/s]C:\Users\jordy\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# C:\Users\jordy\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# t-SNE Progress:   0%|▏                                                            | 100/30000 [00:00<01:50, 270.26it/s]C:\Users\jordy\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# C:\Users\jordy\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# ...

# %% [markdown]
# # TSNE Perplexity 80

# %%
# Drop the target column
features = df_uci.drop(columns=['default.payment.next.month'])

# Standardize the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Perform t-SNE
tsne = TSNE(n_components=2, random_state=42, n_iter=2000, perplexity=20.0)

# Fit and transform the scaled features with a progress bar
tsne_result = []
with tqdm(total=len(scaled_features), desc="t-SNE Progress") as pbar:
    for i in range(0, len(scaled_features), 100):  # Batch processing for better performance
        batch_result = tsne.fit_transform(scaled_features[i:i+100])
        tsne_result.append(batch_result)
        pbar.update(len(batch_result))

# Concatenate the t-SNE results
tsne_result = np.concatenate(tsne_result, axis=0)

# Create a new DataFrame with the t-SNE results
tsne_df = pd.DataFrame(data=tsne_result, columns=['Dimension 1', 'Dimension 2'])

# Plot the t-SNE scatter plot
plt.scatter(tsne_df['Dimension 1'], tsne_df['Dimension 2'])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('t-SNE Plot')
plt.show()
# Out:
# t-SNE Progress:   0%|                                                                        | 0/30000 [00:00<?, ?it/s]C:\Users\jordy\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# C:\Users\jordy\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# t-SNE Progress:   0%|▏                                                            | 100/30000 [00:00<03:18, 151.00it/s]C:\Users\jordy\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# C:\Users\jordy\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# ...
